# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

# %%
class_names = ['abstract triangle pattern', 'memphis  pattern', 'space pattern', 'terrazoo pattern']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['C:/project 22/train', 'C:/project 22/test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#  32%|███▏      | 14/44 [00:00<00:00, 123.11it/s]
# Loading C:/project 22/train
# 100%|██████████| 44/44 [00:00<00:00, 119.20it/s]
# 100%|██████████| 44/44 [00:00<00:00, 131.94it/s]
# 100%|██████████| 44/44 [00:00<00:00, 73.30it/s]
# 100%|██████████| 44/44 [00:00<00:00, 78.90it/s]
# 100%|██████████| 16/16 [00:00<00:00, 115.12it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Loading C:/project 22/test
# 100%|██████████| 16/16 [00:00<00:00, 83.57it/s]
# 100%|██████████| 16/16 [00:00<00:00, 82.77it/s]
# 100%|██████████| 16/16 [00:00<00:00, 111.12it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 176
# Number of testing examples: 64
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
def display_random_image(class_names, images, labels):
   
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
  
    
    fig = plt.figure(figsize=(20,20))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (150, 150, 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=20, validation_split = 0.2)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
train_loss, train_acc = model.evaluate(train_images, train_labels, verbose=2)
print("Test accuracy: ", test_acc)
print("train accuracy: ", train_acc)
model.save("model.h5")
# Out:
# Train on 140 samples, validate on 36 samples
# Epoch 1/20
# 140/140 [==============================] - 5s 34ms/sample - loss: 1.9024 - accuracy: 0.0500 - val_loss: 5.5743 - val_accuracy: 0.2222
# Epoch 2/20
# 140/140 [==============================] - 0s 683us/sample - loss: 4.6737 - accuracy: 0.2571 - val_loss: 2.9930 - val_accuracy: 0.0833
# Epoch 3/20
# 140/140 [==============================] - 0s 693us/sample - loss: 2.3291 - accuracy: 0.3071 - val_loss: 1.9583 - val_accuracy: 0.4167
# Epoch 4/20
# 140/140 [==============================] - 0s 647us/sample - loss: 1.6673 - accuracy: 0.2714 - val_loss: 1.6641 - val_accuracy: 0.5278
# Epoch 5/20
# 140/140 [==============================] - 0s 644us/sample - loss: 1.2228 - accuracy: 0.5286 - val_loss: 1.8415 - val_accuracy: 0.3611
# Epoch 6/20
# 140/140 [==============================] - 0s 709us/sample - loss: 1.2736 - accuracy: 0.4000 - val_loss: 1.7470 - val_accuracy: 0.3056
# Epoch 7/20
# 140/140 [==============================] - 0s 622us/sample - loss: 1.1961 - accuracy: 0.4500 - val_loss: 1.7197 - val_accuracy: 0.3333
# Epoch 8/20
# 140/140 [==============================] - 0s 652us/sample - loss: 1.1623 - accuracy: 0.6286 - val_loss: 1.7628 - val_accuracy: 0.2222
# Epoch 9/20
# 140/140 [==============================] - 0s 638us/sample - loss: 1.1137 - accuracy: 0.5500 - val_loss: 1.7011 - val_accuracy: 0.3056
# Epoch 10/20
# 140/140 [==============================] - 0s 625us/sample - loss: 0.9955 - accuracy: 0.6286 - val_loss: 1.4892 - val_accuracy: 0.4444
# Epoch 11/20
# 140/140 [==============================] - 0s 614us/sample - loss: 0.8782 - accuracy: 0.7071 - val_loss: 1.7024 - val_accuracy: 0.3611
# Epoch 12/20
# 140/140 [==============================] - 0s 653us/sample - loss: 0.8482 - accuracy: 0.6643 - val_loss: 1.9706 - val_accuracy: 0.1667
# Epoch 13/20
# 140/140 [==============================] - 0s 638us/sample - loss: 0.8339 - accuracy: 0.5786 - val_loss: 1.5140 - val_accuracy: 0.4167
# Epoch 14/20
# 140/140 [==============================] - 0s 631us/sample - loss: 0.8735 - accuracy: 0.6714 - val_loss: 1.3409 - val_accuracy: 0.5278
# Epoch 15/20
# 140/140 [==============================] - 0s 600us/sample - loss: 0.7394 - accuracy: 0.7357 - val_loss: 1.5616 - val_accuracy: 0.4444
# Epoch 16/20
# 140/140 [==============================] - 0s 610us/sample - loss: 0.6035 - accuracy: 0.8000 - val_loss: 1.8428 - val_accuracy: 0.4444
# Epoch 17/20
# 140/140 [==============================] - 0s 611us/sample - loss: 0.5599 - accuracy: 0.8214 - val_loss: 1.6371 - val_accuracy: 0.5556
# Epoch 18/20
# 140/140 [==============================] - 0s 595us/sample - loss: 0.5421 - accuracy: 0.8000 - val_loss: 1.4835 - val_accuracy: 0.6111
# Epoch 19/20
# 140/140 [==============================] - 0s 595us/sample - loss: 0.4612 - accuracy: 0.8286 - val_loss: 1.4617 - val_accuracy: 0.5556
# Epoch 20/20
# 140/140 [==============================] - 0s 616us/sample - loss: 0.4193 - accuracy: 0.8643 - val_loss: 1.6872 - val_accuracy: 0.5000
# 64/64 - 0s - loss: 1.3777 - accuracy: 0.5000
# 176/176 - 0s - loss: 0.7184 - accuracy: 0.7614
# Test accuracy:  0.5
# train accuracy:  0.7613636

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 64/64 [==============================] - 0s 311us/sample - loss: 1.3777 - accuracy: 0.5000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               5308544
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 5,319,462
# Trainable params: 5,319,462
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
img_path="C:/project 22/test/space pattern/210.png"

# %%
img = image.load_img(img_path,target_size=(200,200))
img= image.img_to_array(img)
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
x = img/255
plt.imshow(x)
plt.axis('off')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
input_batch = x.reshape((1,*x.shape))
print(input_batch.shape)
# Out:
# (1, 200, 200, 3)

# %%
i = 0
for output_batch in datagen.flow(input_batch,batch_size=1):
    plt.figure()
    imgplot=plt.imshow(image.img_to_array(output_batch[0]))
    i+=1
    if i==40:
        break
    plt.show()

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history1 = model.fit(train_images, train_labels, batch_size=128, epochs=60, validation_split = 0.2)
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
train_loss, train_acc = model.evaluate(train_images, train_labels, verbose=2)
print("Test accuracy: ", test_acc)
print("train accuracy: ", train_acc)
model.save("model.h6")
# Out:
# Train on 140 samples, validate on 36 samples
# Epoch 1/60
# 140/140 [==============================] - 1s 4ms/sample - loss: 0.5244 - accuracy: 0.8071 - val_loss: 1.5133 - val_accuracy: 0.4722
# Epoch 2/60
# 140/140 [==============================] - 0s 686us/sample - loss: 0.3930 - accuracy: 0.9143 - val_loss: 2.1589 - val_accuracy: 0.1667
# Epoch 3/60
# 140/140 [==============================] - 0s 645us/sample - loss: 0.5715 - accuracy: 0.7714 - val_loss: 1.3976 - val_accuracy: 0.5000
# Epoch 4/60
# 140/140 [==============================] - 0s 680us/sample - loss: 0.4343 - accuracy: 0.8786 - val_loss: 1.1949 - val_accuracy: 0.5833
# Epoch 5/60
# 140/140 [==============================] - 0s 609us/sample - loss: 0.3373 - accuracy: 0.9429 - val_loss: 1.6109 - val_accuracy: 0.4444
# Epoch 6/60
# 140/140 [==============================] - 0s 645us/sample - loss: 0.3997 - accuracy: 0.9000 - val_loss: 1.5424 - val_accuracy: 0.3056
# Epoch 7/60
# 140/140 [==============================] - 0s 652us/sample - loss: 0.3198 - accuracy: 0.8786 - val_loss: 1.2433 - val_accuracy: 0.3889
# Epoch 8/60
# 140/140 [==============================] - 0s 629us/sample - loss: 0.2286 - accuracy: 0.9214 - val_loss: 1.2921 - val_accuracy: 0.5556
# Epoch 9/60
# 140/140 [==============================] - 0s 644us/sample - loss: 0.2331 - accuracy: 0.9286 - val_loss: 1.6554 - val_accuracy: 0.5278
# Epoch 10/60
# 140/140 [==============================] - 0s 634us/sample - loss: 0.2284 - accuracy: 0.9286 - val_loss: 1.8638 - val_accuracy: 0.5000
# Epoch 11/60
# 140/140 [==============================] - 0s 622us/sample - loss: 0.1636 - accuracy: 0.9500 - val_loss: 1.7286 - val_accuracy: 0.4722
# Epoch 12/60
# 140/140 [==============================] - 0s 611us/sample - loss: 0.1474 - accuracy: 0.9643 - val_loss: 1.7210 - val_accuracy: 0.4722
# Epoch 13/60
# 140/140 [==============================] - 0s 644us/sample - loss: 0.1647 - accuracy: 0.9429 - val_loss: 2.1426 - val_accuracy: 0.5000
# Epoch 14/60
# 140/140 [==============================] - 0s 645us/sample - loss: 0.1609 - accuracy: 0.9500 - val_loss: 2.4599 - val_accuracy: 0.3889
# Epoch 15/60
# 140/140 [==============================] - 0s 640us/sample - loss: 0.1094 - accuracy: 0.9643 - val_loss: 2.2035 - val_accuracy: 0.4722
# Epoch 16/60
# 140/140 [==============================] - 0s 626us/sample - loss: 0.0880 - accuracy: 0.9714 - val_loss: 1.6970 - val_accuracy: 0.6389
# Epoch 17/60
# 140/140 [==============================] - 0s 607us/sample - loss: 0.1113 - accuracy: 0.9714 - val_loss: 1.8867 - val_accuracy: 0.5556
# Epoch 18/60
# 140/140 [==============================] - 0s 673us/sample - loss: 0.0643 - accuracy: 0.9786 - val_loss: 3.0343 - val_accuracy: 0.1944
# Epoch 19/60
# 140/140 [==============================] - 0s 659us/sample - loss: 0.1281 - accuracy: 0.9500 - val_loss: 2.0864 - val_accuracy: 0.3889
# Epoch 20/60
# 140/140 [==============================] - 0s 645us/sample - loss: 0.0624 - accuracy: 0.9714 - val_loss: 1.4547 - val_accuracy: 0.5833
# Epoch 21/60
# 140/140 [==============================] - 0s 615us/sample - loss: 0.0584 - accuracy: 0.9857 - val_loss: 1.3997 - val_accuracy: 0.5833
# Epoch 22/60
# 140/140 [==============================] - 0s 618us/sample - loss: 0.0641 - accuracy: 0.9714 - val_loss: 1.7430 - val_accuracy: 0.4722
# Epoch 23/60
# 140/140 [==============================] - 0s 645us/sample - loss: 0.0413 - accuracy: 1.0000 - val_loss: 3.0023 - val_accuracy: 0.2500
# Epoch 24/60
# 140/140 [==============================] - 0s 644us/sample - loss: 0.0987 - accuracy: 0.9500 - val_loss: 1.6702 - val_accuracy: 0.4722
# Epoch 25/60
# 140/140 [==============================] - 0s 646us/sample - loss: 0.0362 - accuracy: 0.9929 - val_loss: 1.4705 - val_accuracy: 0.6389
# Epoch 26/60
# 140/140 [==============================] - 0s 644us/sample - loss: 0.1147 - accuracy: 0.9643 - val_loss: 1.5875 - val_accuracy: 0.6111
# Epoch 27/60
# 140/140 [==============================] - 0s 643us/sample - loss: 0.0929 - accuracy: 0.9714 - val_loss: 2.2809 - val_accuracy: 0.4444
# Epoch 28/60
# 140/140 [==============================] - 0s 645us/sample - loss: 0.1281 - accuracy: 0.9643 - val_loss: 2.3296 - val_accuracy: 0.5278
# Epoch 29/60
# 140/140 [==============================] - 0s 626us/sample - loss: 0.1151 - accuracy: 0.9643 - val_loss: 2.6607 - val_accuracy: 0.5000
# Epoch 30/60
# 140/140 [==============================] - 0s 629us/sample - loss: 0.0923 - accuracy: 0.9643 - val_loss: 3.0349 - val_accuracy: 0.3056
# Epoch 31/60
# 140/140 [==============================] - 0s 616us/sample - loss: 0.0403 - accuracy: 0.9929 - val_loss: 3.1471 - val_accuracy: 0.3056
# Epoch 32/60
# 140/140 [==============================] - 0s 644us/sample - loss: 0.0315 - accuracy: 1.0000 - val_loss: 2.7761 - val_accuracy: 0.4444
# Epoch 33/60
# 140/140 [==============================] - 0s 644us/sample - loss: 0.0419 - accuracy: 0.9714 - val_loss: 3.0814 - val_accuracy: 0.4722
# Epoch 34/60
# 140/140 [==============================] - 0s 620us/sample - loss: 0.0267 - accuracy: 1.0000 - val_loss: 3.6398 - val_accuracy: 0.3611
# Epoch 35/60
# 140/140 [==============================] - 0s 684us/sample - loss: 0.0472 - accuracy: 0.9786 - val_loss: 2.3833 - val_accuracy: 0.5278
# Epoch 36/60
# 140/140 [==============================] - 0s 635us/sample - loss: 0.0199 - accuracy: 1.0000 - val_loss: 1.9689 - val_accuracy: 0.5278
# Epoch 37/60
# 140/140 [==============================] - 0s 645us/sample - loss: 0.0333 - accuracy: 0.9857 - val_loss: 2.1365 - val_accuracy: 0.5278
# Epoch 38/60
# 140/140 [==============================] - 0s 635us/sample - loss: 0.0284 - accuracy: 1.0000 - val_loss: 2.2382 - val_accuracy: 0.4444
# Epoch 39/60
# 140/140 [==============================] - 0s 643us/sample - loss: 0.0233 - accuracy: 1.0000 - val_loss: 2.2083 - val_accuracy: 0.4444
# Epoch 40/60
# 140/140 [==============================] - 0s 646us/sample - loss: 0.0179 - accuracy: 1.0000 - val_loss: 2.1465 - val_accuracy: 0.5556
# Epoch 41/60
# 140/140 [==============================] - 0s 643us/sample - loss: 0.0147 - accuracy: 1.0000 - val_loss: 2.1129 - val_accuracy: 0.5833
# Epoch 42/60
# 140/140 [==============================] - 0s 653us/sample - loss: 0.0135 - accuracy: 1.0000 - val_loss: 2.0661 - val_accuracy: 0.5000
# Epoch 43/60
# 140/140 [==============================] - 0s 651us/sample - loss: 0.0132 - accuracy: 1.0000 - val_loss: 2.1214 - val_accuracy: 0.5000
# Epoch 44/60
# 140/140 [==============================] - 0s 648us/sample - loss: 0.0117 - accuracy: 1.0000 - val_loss: 2.2323 - val_accuracy: 0.5278
# Epoch 45/60
# 140/140 [==============================] - 0s 656us/sample - loss: 0.0090 - accuracy: 1.0000 - val_loss: 2.2684 - val_accuracy: 0.5833
# Epoch 46/60
# 140/140 [==============================] - 0s 655us/sample - loss: 0.0079 - accuracy: 1.0000 - val_loss: 2.3548 - val_accuracy: 0.5833
# Epoch 47/60
# 140/140 [==============================] - 0s 649us/sample - loss: 0.0085 - accuracy: 1.0000 - val_loss: 2.5623 - val_accuracy: 0.5556
# Epoch 48/60
# 140/140 [==============================] - 0s 648us/sample - loss: 0.0086 - accuracy: 1.0000 - val_loss: 2.8662 - val_accuracy: 0.5000
# Epoch 49/60
# 140/140 [==============================] - 0s 655us/sample - loss: 0.0071 - accuracy: 1.0000 - val_loss: 2.7963 - val_accuracy: 0.4722
# Epoch 50/60
# 140/140 [==============================] - 0s 655us/sample - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.5979 - val_accuracy: 0.5556
# Epoch 51/60
# 140/140 [==============================] - 0s 641us/sample - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.8338 - val_accuracy: 0.4722
# Epoch 52/60
# 140/140 [==============================] - 0s 677us/sample - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.8642 - val_accuracy: 0.4444
# Epoch 53/60
# 140/140 [==============================] - 0s 663us/sample - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.4091 - val_accuracy: 0.5556
# Epoch 54/60
# 140/140 [==============================] - 0s 673us/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.1820 - val_accuracy: 0.5833
# Epoch 55/60
# 140/140 [==============================] - 0s 606us/sample - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.2665 - val_accuracy: 0.5833
# Epoch 56/60
# 140/140 [==============================] - 0s 613us/sample - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.4985 - val_accuracy: 0.5000
# Epoch 57/60
# 140/140 [==============================] - 0s 606us/sample - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.7287 - val_accuracy: 0.5000
# Epoch 58/60
# 140/140 [==============================] - 0s 617us/sample - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.8967 - val_accuracy: 0.4722
# Epoch 59/60
# 140/140 [==============================] - 0s 610us/sample - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.0415 - val_accuracy: 0.4722
# Epoch 60/60
# 140/140 [==============================] - 0s 615us/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.1367 - val_accuracy: 0.3889
# 64/64 - 0s - loss: 2.6938 - accuracy: 0.4844
# 176/176 - 0s - loss: 0.6431 - accuracy: 0.8750
# Test accuracy:  0.484375
# train accuracy:  0.875
# WARNING:tensorflow:From C:\Users\parit\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: model.h6\assets

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)
